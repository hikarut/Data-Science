# %% [markdown]
# [B.LEAGUE（Bリーグ）公式サイト](https://www.bleague.jp/about/management/)

# %%
# import matplotlib.pyplot as plt
# import numpy as np
import pandas as pd
# from matplotlib.font_manager import FontProperties
# import matplotlib.font_manager as fm
# import matplotlib

b1_data = pd.DataFrame({
            'チーム名': [
                '北海道', 
                '秋田', 
                '宇都宮', 
                '千葉', 
                'A東京', 
                'SR渋谷', 
                '川崎',
                '横浜', 
                '新潟', 
                '富山', 
                '三遠',
                '三河',
                '名古屋D',
                '滋賀',
                '京都',
                '大阪',
                '福岡',
                '琉球'
            ],
#             '売上': [790129, 679216, 1370736],
            '入場料収入': [
                226984,
                170164,
                433857,
                416258,
                250589,
                216555,
                208836,
                142465,
                198458,
                163866,
                139909,
                166581,
                126779,
                131398,
                97419,
                128796,
                100836,
                355863
            ],
            'スポンサー収入': [
                308104,
                296598,
                467110,
                776973,
                878325,
                446445,
                294569,
                455079,
                256180,
                218031,
                366379,
                982418,
                712358,
                268174,
                320924,
                650668,
                272633,
                467890
            ],
            '物販収入': [
                65078, 
                41070, 
                162332, 
                170614, 
                44454, 
                1676, 
                94221, 
                16256, 
                34876, 
                30383, 
                42105,
                65531, 
                11898, 
                12218, 
                19406, 
                40588, 
                16833, 
                128155
            ],
            'ユース・スクール関連収入': [
                47317, 
                24400, 
                101808, 
                48944,
                12478,
                7127,
                12300,
                135486,
                44534,
                18939,
                37406,
                11581,
                20854,
                34003,
                43710,
                100073,
                7552,
                8664
            ],
            '配分金': [
                54037,
                51500,
                66341,
                71880,
                51407,
                51578,
                30000,
                37012,
                42418,
                45040,
                35075,
                46906,
                34207,
                33491,
                30000,
                50598,
                30000,
                56176
            ],
            'その他': [
                88609,
                95484,
                139288,
                276994,
                140657,
                16588,
                25063,
                25364,
                43991,
                44863,
                81711,
                349472,
                27460,
                83208,
                25817,
                393242,
                29076,
                100313
            ],
            })
b1_data_name = b1_data.set_index('チーム名')

# データの正規化
b1_data_name_bar = b1_data_name.div(b1_data_name.sum(1), axis=0)

# %%
# フォントファイルを指定
fp = FontProperties(fname=r'/root/fonts/mplus-1c-regular.ttf', size=15)

# キャッシュ削除する場合 ~/.cache/matplotlib/fontlist-v310.jsonのキャッシュを削除
matplotlib.font_manager._rebuild()

# 利用可能なフォント確認
# print(fm.findSystemFonts())

# print(plt.style.available)
plt.style.use('seaborn-whitegrid')

# グラフのサイズ
plt.rcParams["font.size"] = 15
plt.rcParams["figure.figsize"] = [15,7] # 図の縦横のサイズ([横(inch),縦(inch)])

# タイトルと軸の設定
plt.title("Bリーグ", fontproperties=fp)
plt.xlabel("クラブ名", fontproperties=fp)
plt.ylabel("売上", fontproperties=fp)
plt.xticks(range(len(b1_data.name)), b1_data.name.values, fontproperties=fp)

# グラフ描画
p1 = plt.bar(x=b1_data['チーム名'].values, height=b1_data.admission, align="center")
p2 = plt.bar(x=b1_data.name.values, height=b1_data.sponsor, bottom=b1_data.admission, align="center")
p3 = plt.bar(x=b1_data.name.values, height=b1_data.sales, bottom=b1_data.sponsor, align="center")

# 凡例追加
plt.legend((p1[0], p2[0], p3[0]), ("入場収入", "スポンサー収入", "売上"), prop=fp)

# 数値追加
plt.text(0, 100000, 'aa', color="white", horizontalalignment="center", verticalalignment="center")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-90aeffecd73f> in <module>
#      19 plt.xlabel("クラブ名", fontproperties=fp)
#      20 plt.ylabel("売上", fontproperties=fp)
# ---> 21 plt.xticks(range(len(b1_data.name)), b1_data.name.values, fontproperties=fp)
#      22
#      23 # グラフ描画
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'name'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib

# sns.set()
# sns.set(font='IPAexGothic')

# グラフのサイズ
# plt.rcParams["font.size"] = 15
# plt.rcParams["figure.figsize"] = [15,7] # 図の縦横のサイズ([横(inch),縦(inch)])
# plt.style.use('seaborn-whitegrid')

# fig, ax = plt.subplots(figsize=(16, 9))
# b1_data_name.plot(kind='bar', stacked=True, ax=ax)
# plt.show()

# fig, ax = plt.subplots(figsize=(16, 9))
# b1_data_name.plot(kind='bar', stacked=True, ax=ax)

# 積み上げで表示
b1_data_name.plot(kind='bar', stacked=True)

# 円グラフで表示
# b1_data_name.T.plot.pie(subplots=True)

# 割合で表示
# b1_data_name_bar.plot(kind='bar', stacked=True).legend(bbox_to_anchor=(0, 0.5), loc='upper right')

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib  # <- これ

plt.plot([1, 2, 3, 4])
plt.xlabel('簡単なグラフ')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 31777 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21336 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 12394 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 12464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 12521 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
