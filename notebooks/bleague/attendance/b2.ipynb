# %%
import pandas as pd

b2 = pd.read_csv("b2.csv", sep=",")
# b1.head(10)
b2
# Out:
#      setu  date home_team home_victory  home_score away_team  away_score  \
# 0       1  9.20        信州          win          85        広島          77
# 1       1  9.20        広島         lose          77        信州          85
# 2       1  9.21        信州         lose          77        広島          81
# 3       1  9.21        広島          win          81        信州          77
# 4       1  9.21     FE名古屋          win          85        青森          68
# ..    ...   ...       ...          ...         ...       ...         ...
# 841    28  3.15        愛媛          win          91        香川         100
# 842    28  3.15        越谷         lose          63       東京Z          88
# 843    28  3.15       東京Z          win          88        越谷          63
# 844    28  3.15      東京EX          win          78     FE名古屋         112
# 845    28  3.15     FE名古屋         lose         112      東京EX          78
#
#     home_away  attendance arena  arena_rate
# 0        home        2066  ホワイト           0
# 1        away        2066  ホワイト           0
# 2        home        2206  ホワイト           0
# 3        away        2206  ホワイト           0
# 4        home        1943    千種           0
# ..        ...         ...   ...         ...
# 841      away           0   観音寺           0
# 842      home           0   越谷M           0
# 843      away           0   越谷M           0
# 844      home           0   小豆沢           0
# 845      away           0   小豆沢           0
#
# [846 rows x 11 columns]

# %%
b2.arena.unique()
# Out:
# array(['ホワイト', '千種', 'ADみと', '市民前橋', '西宮中央', '熊本県総', '山形スポ', '高松総合',
#        '小豆沢', 'コミセン', '越谷M', 'ゼビオ', '片柳アリ', 'カクヒロ', '郡山総合', 'ならアリ',
#        'サンプラ', '加古川', '山形県総', '照葉積水', '東広島', 'いわき', 'ことアリ', '越谷S', '大田区',
#        '東区', '愛媛県総', '猪苗代', '五所川原', 'とらまる', '五島中央', '日立池川', '南陽市体',
#        '久喜総合', 'Jアリ', '春日部', '黒石', '中村', 'あいづ', '千代田', '大川市民', '南三陸町',
#        '福島国体', '世田谷区', '立川立飛', '宇土市民', '獨協大学', '五條', '伊勢崎', '福山', 'みどり',
#        '合志市総', '伊予市民', '神栖防災', '埼玉県大', '八戸東', '行田市', '北九総合', '三友体文',
#        '三沢国際', 'みづま総', '呉', 'ふじアリ', '伊方SC', '土庄総合', '白河中央', '宝塚市立', 'カメイ',
#        '観音寺'], dtype=object)

# %%
# b1.groupby('home_team').mean()
# b1[b1['home_away'] == 'home'].groupby('home_team').mean()
b2[(b2['home_away'] == 'home') & (b2['attendance'] != 0)].groupby('home_team').mean()
# Out:
#                 setu      date  home_score  away_score   attendance  \
# home_team
# FE名古屋      14.458333  6.773333   79.916667   74.291667  1179.291667
# 仙台         12.142857  8.271429   78.571429   69.000000  2448.285714
# 信州         13.136364  7.245455   82.727273   61.863636  1746.227273
# 奈良         12.318182  7.942727   87.818182   85.318182  1076.409091
# 山形         12.708333  7.432083   76.583333   83.750000  1537.166667
# 広島         13.227273  7.051364   87.727273   72.272727  2296.409091
# 愛媛         11.782609  7.524783   81.869565   81.608696  1030.782609
# 東京EX       10.428571  9.035714   83.761905   80.095238   722.428571
# 東京Z        14.652174  6.071739   68.043478   75.130435  1371.521739
# 熊本         11.958333  8.146250   82.208333   82.125000  1858.375000
# 福岡         13.190476  7.470952   76.333333   85.333333  1068.285714
# 福島         12.136364  7.105455   76.772727   80.045455  1088.681818
# 群馬         11.434783  8.164348   82.434783   73.347826  1262.739130
# 茨城         13.608696  7.836957   84.695652   76.304348  2108.217391
# 西宮         11.695652  7.529565   78.652174   72.608696  1574.652174
# 越谷         11.291667  9.042500   75.291667   84.208333   753.125000
# 青森         13.045455  8.085455   75.409091   82.045455  1313.818182
# 香川         11.380952  8.227619   82.714286   77.714286   873.190476
#
#            arena_rate
# home_team
# FE名古屋             0.0
# 仙台                0.0
# 信州                0.0
# 奈良                0.0
# 山形                0.0
# 広島                0.0
# 愛媛                0.0
# 東京EX              0.0
# 東京Z               0.0
# 熊本                0.0
# 福岡                0.0
# 福島                0.0
# 群馬                0.0
# 茨城                0.0
# 西宮                0.0
# 越谷                0.0
# 青森                0.0
# 香川                0.0

# %%
# win_count = b1[b1['home_victory'] == 'win'].groupby('home_team').count()['setu']
win_count = b2[b2['home_victory'] == 'win'].groupby('home_team').count()
win_count[['setu']]
# Out:
#            setu
# home_team
# FE名古屋        21
# 仙台           35
# 信州           38
# 奈良           19
# 山形           13
# 広島           29
# 愛媛           23
# 東京EX         23
# 東京Z          14
# 熊本           23
# 福岡           17
# 福島           20
# 群馬           32
# 茨城           23
# 西宮           26
# 越谷           19
# 青森           22
# 香川           26

# %%
# arena_rate = b1.groupby('home_team').mean()['arena_rate']
# arena_rate = b1.groupby('home_team').mean()
# arena_rate = b1[b1['home_away'] == 'home'].groupby('home_team').mean()
arena_rate = b2[(b2['home_away'] == 'home') & (b2['attendance'] != 0)].groupby('home_team').mean()
# arena_rate[['arena_rate']]
arena_rate[['attendance']]
# Out:
#             attendance
# home_team
# FE名古屋      1179.291667
# 仙台         2448.285714
# 信州         1746.227273
# 奈良         1076.409091
# 山形         1537.166667
# 広島         2296.409091
# 愛媛         1030.782609
# 東京EX        722.428571
# 東京Z        1371.521739
# 熊本         1858.375000
# 福岡         1068.285714
# 福島         1088.681818
# 群馬         1262.739130
# 茨城         2108.217391
# 西宮         1574.652174
# 越谷          753.125000
# 青森         1313.818182
# 香川          873.190476

# %%
# output = pd.merge(win_count[['setu']], arena_rate[['arena_rate']], how="inner" ,on="home_team")
output = pd.merge(win_count[['setu']], arena_rate[['attendance']], how="inner" ,on="home_team")
# output

output2 = output.reset_index().rename(columns={'setu': 'victory'})
output2.sort_values('attendance', ascending=False)
# Out:
#    home_team  victory   attendance
# 1         仙台       35  2448.285714
# 5         広島       29  2296.409091
# 13        茨城       23  2108.217391
# 9         熊本       23  1858.375000
# 2         信州       38  1746.227273
# 14        西宮       26  1574.652174
# 4         山形       13  1537.166667
# 8        東京Z       14  1371.521739
# 16        青森       22  1313.818182
# 12        群馬       32  1262.739130
# 0      FE名古屋       21  1179.291667
# 11        福島       20  1088.681818
# 3         奈良       19  1076.409091
# 10        福岡       17  1068.285714
# 6         愛媛       23  1030.782609
# 17        香川       26   873.190476
# 15        越谷       19   753.125000
# 7       東京EX       23   722.428571

# %%
import japanize_matplotlib
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 9))
plt.xlabel("勝数", fontsize=16) # x軸ラベル
plt.ylabel("収容人数平均", fontsize=16) # y軸ラベル

# output.plot.scatter(x='setu', y='arena_rate', style='home_team')
# plt.scatter(x=output2['victory'], y=output2['arena_rate'])
plt.scatter(x=output2['victory'], y=output2['attendance'])
# plt.plot(output['setu'], output['arena_rate'], marker='.')

# %%
import seaborn as sns
import japanize_matplotlib

fig, ax = plt.subplots(figsize=(16, 9))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlabel("勝数", fontsize=16) # x軸ラベル
plt.ylabel("収容人数平均", fontsize=16) # y軸ラベル

# sns.scatterplot(x='victory', y='arena_rate', hue='home_team', data=output2, ax=ax)
grid = sns.scatterplot(x='victory', y='attendance', hue='home_team', data=output2, ax=ax)

# %%
# 外れ値(三遠)除外
# output2_drop = output2.drop(3, axis=0)
# 外れ値(三遠,新潟)除外
# output2_drop = output2.drop(3, axis=0).drop(13, axis=0)
# 三遠、東京
# output2_drop = output2.drop(3, axis=0).drop(0, axis=0)
output2_drop = output2
output2_drop

# statsmodelsを使った回帰分析
import statsmodels.api as sm
from sklearn import linear_model

victory = output2_drop[['victory']]
# arena_rate = output2_drop[['arena_rate']]
arena_rate = output2_drop[['attendance']]

model = linear_model.LinearRegression()
model.fit(victory.values, arena_rate.values)

sm_model = sm.OLS(arena_rate, sm.add_constant(victory))
result = sm_model.fit(disp=0)
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             attendance   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     4.373
# Date:                Tue, 14 Jul 2020   Prob (F-statistic):             0.0528
# Time:                        23:41:34   Log-Likelihood:                -135.15
# No. Observations:                  18   AIC:                             274.3
# Df Residuals:                      16   BIC:                             276.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        573.2490    413.245      1.387      0.184    -302.790    1449.288
# victory       35.4400     16.947      2.091      0.053      -0.486      71.366
# ==============================================================================
# Omnibus:                        2.449   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.294   Jarque-Bera (JB):                1.236
# Skew:                           0.268   Prob(JB):                        0.539
# Kurtosis:                       1.833   Cond. No.                         91.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))

# %%
# 回帰直線
plt.rcParams["figure.figsize"] = [15,7] # 図の縦横のサイズ([横(inch),縦(inch)])
plt.rcParams["font.size"] = 15 # フォントサイズ デフォルト12
# plt.title("回帰分析")
plt.xlabel("victory")
plt.ylabel("attendance")
plt.scatter(victory, arena_rate, s=20, alpha=0.5)
plt.plot(victory.values, model.predict(victory.values), color='black')

# %%
sanen_data = b1[(b1['home_team'] == '三遠') & (b1['home_away'] == 'home')]
# sanen_data = b1[(b1['home_team'] == '三遠')]
sanen = sanen_data.set_index('date')
sanen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2d0f59446e4c> in <module>
# ----> 1 sanen_data = b1[(b1['home_team'] == '三遠') & (b1['home_away'] == 'home')]
#       2 # sanen_data = b1[(b1['home_team'] == '三遠')]
#       3 sanen = sanen_data.set_index('date')
#       4 sanen
#
# NameError: name 'b1' is not defined

# %%
# 積み上げで表示
fig, ax = plt.subplots(figsize=(16, 9))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
sanen.attendance.plot(title='', kind='bar', stacked=True, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bc89d722899b> in <module>
#       2 fig, ax = plt.subplots(figsize=(16, 9))
#       3 ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
# ----> 4 sanen.attendance.plot(title='', kind='bar', stacked=True, ax=ax)
#
# NameError: name 'sanen' is not defined
