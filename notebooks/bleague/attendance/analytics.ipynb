# %%
import pandas as pd

b1 = pd.read_csv("b1.csv", sep=",")
# b1.head(10)
b1
# Out:
#      setu   date home_team home_victory  home_score away_team  away_score  \
# 0       1  10.03        川崎          win          78       宇都宮          57
# 1       1  10.03       宇都宮         lose          57        川崎          78
# 2       1  10.05        秋田          win          81        大阪          58
# 3       1  10.05        大阪         lose          58        秋田          81
# 4       1  10.05       A東京          win          87        新潟          59
# ..    ...    ...       ...          ...         ...       ...         ...
# 729    28   3.15        島根         lose          80        大阪          93
# 730    28   3.15        川崎          win          97       北海道          71
# 731    28   3.15       北海道         lose          71        川崎          97
# 732    28   3.15        三河          win          96        横浜          82
# 733    28   3.15        横浜         lose          82        三河          96
#
#     home_away  attendance arena  arena_rate
# 0        home        9514   横アリ          56
# 1        away        9514   横アリ          56
# 2        home        4335   CNA          95
# 3        away        4335   CNA          95
# 4        home        2940  立川立飛          98
# ..        ...         ...   ...         ...
# 729      away           0  おおきに           0
# 730      home           0  とどろき           0
# 731      away           0  とどろき           0
# 732      home           0  WA刈谷           0
# 733      away           0  WA刈谷           0
#
# [734 rows x 11 columns]

# %%
b1.arena.unique()
# b1.arena.nunique()
# Out:
# array(['横アリ', 'CNA', '立川立飛', '青山学院', '松江総体', 'ハンアリ', '富山市総', '沖縄市',
#        '北海きた', 'とどろき', '横浜文体', 'YMIT', 'WA刈谷', 'ドルアリ', 'おおきに', 'アオーレ',
#        '横浜国プ', '大阪府立', '船橋', '墨田区', '豊橋', 'ブレアリ', '浜松', 'ウカル', '福知山',
#        '富山西部', 'RP上越', 'カミアリ', '北ガス', '県北', '鹿島総体', '島津', '島根県立', '駒沢',
#        '千葉', '秋田県体', 'トッ平総', '住吉SC', '能代総体', '守山市民', '豊見城', '東総合', 'SH豊田'],
#       dtype=object)

# %%
# b1.groupby('home_team').mean()
# b1[b1['home_away'] == 'home'].groupby('home_team').mean()
b1[(b1['home_away'] == 'home') & (b1['attendance'] != 0)].groupby('home_team').mean()
# Out:
#                 setu      date  home_score  away_score   attendance  \
# home_team
# A東京        10.285714  7.729524   83.142857   71.904762  2761.333333
# SR渋谷       10.631579  8.513158   83.947368   76.947368  2905.578947
# 三河         12.600000  7.338000   82.750000   83.050000  2773.550000
# 三遠         13.705882  7.388824   66.000000   80.058824  3080.647059
# 京都          9.944444  8.926667   76.055556   81.777778  1868.611111
# 北海道        12.333333  8.102381   77.904762   80.904762  3763.952381
# 千葉         12.450000  8.374500   85.300000   74.350000  5115.650000
# 名古屋D       12.105263  7.573158   75.105263   77.684211  3342.105263
# 大阪         11.700000  7.872000   77.450000   76.300000  3708.600000
# 宇都宮        12.666667  8.148333   82.500000   73.277778  4237.166667
# 富山         11.950000  7.795500   75.550000   76.850000  2873.700000
# 島根         12.285714  7.587143   70.619048   75.952381  2352.238095
# 川崎         12.894737  7.142632   84.473684   74.526316  4963.210526
# 新潟         11.666667  7.933889   68.222222   72.000000  2745.000000
# 横浜         11.736842  8.310526   75.736842   79.947368  3105.105263
# 滋賀         11.900000  7.802000   79.200000   72.600000  2382.650000
# 琉球         11.476190  7.836667   78.238095   71.714286  3295.047619
# 秋田         12.000000  8.361000   74.550000   71.400000  3400.950000
#
#            arena_rate
# home_team
# A東京         90.428571
# SR渋谷       107.157895
# 三河         105.350000
# 三遠         121.470588
# 京都          34.388889
# 北海道         52.523810
# 千葉         105.950000
# 名古屋D        44.526316
# 大阪          52.300000
# 宇都宮        150.944444
# 富山          68.550000
# 島根          57.904762
# 川崎          71.631579
# 新潟         126.388889
# 横浜          46.315789
# 滋賀          54.500000
# 琉球         107.952381
# 秋田          77.700000

# %%
# win_count = b1[b1['home_victory'] == 'win'].groupby('home_team').count()['setu']
win_count = b1[b1['home_victory'] == 'win'].groupby('home_team').count()
win_count[['setu']]
# Out:
#            setu
# home_team
# A東京          33
# SR渋谷         26
# 三河           18
# 三遠            5
# 京都           20
# 北海道          16
# 千葉           24
# 名古屋D         17
# 大阪           25
# 宇都宮          30
# 富山           18
# 島根           14
# 川崎           30
# 新潟           13
# 横浜           12
# 滋賀           21
# 琉球           27
# 秋田           18

# %%
# arena_rate = b1.groupby('home_team').mean()['arena_rate']
# arena_rate = b1.groupby('home_team').mean()
# arena_rate = b1[b1['home_away'] == 'home'].groupby('home_team').mean()
arena_rate = b1[(b1['home_away'] == 'home') & (b1['attendance'] != 0)].groupby('home_team').mean()
# arena_rate[['arena_rate']]
arena_rate[['attendance']]
# Out:
#             attendance
# home_team
# A東京        2761.333333
# SR渋谷       2905.578947
# 三河         2773.550000
# 三遠         3080.647059
# 京都         1868.611111
# 北海道        3763.952381
# 千葉         5115.650000
# 名古屋D       3342.105263
# 大阪         3708.600000
# 宇都宮        4237.166667
# 富山         2873.700000
# 島根         2352.238095
# 川崎         4963.210526
# 新潟         2745.000000
# 横浜         3105.105263
# 滋賀         2382.650000
# 琉球         3295.047619
# 秋田         3400.950000

# %%
# output = pd.merge(win_count[['setu']], arena_rate[['arena_rate']], how="inner" ,on="home_team")
output = pd.merge(win_count[['setu']], arena_rate[['attendance']], how="inner" ,on="home_team")
# output

output2 = output.reset_index().rename(columns={'setu': 'victory'})
output2.sort_values('attendance', ascending=False)
# Out:
#    home_team  victory   attendance
# 6         千葉       24  5115.650000
# 12        川崎       30  4963.210526
# 9        宇都宮       30  4237.166667
# 5        北海道       16  3763.952381
# 8         大阪       25  3708.600000
# 17        秋田       18  3400.950000
# 7       名古屋D       17  3342.105263
# 16        琉球       27  3295.047619
# 14        横浜       12  3105.105263
# 3         三遠        5  3080.647059
# 1       SR渋谷       26  2905.578947
# 10        富山       18  2873.700000
# 2         三河       18  2773.550000
# 0        A東京       33  2761.333333
# 13        新潟       13  2745.000000
# 15        滋賀       21  2382.650000
# 11        島根       14  2352.238095
# 4         京都       20  1868.611111

# %%
import japanize_matplotlib
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 9))
plt.xlabel("勝数", fontsize=16) # x軸ラベル
plt.ylabel("収容率平均", fontsize=16) # y軸ラベル

# output.plot.scatter(x='setu', y='arena_rate', style='home_team')
# plt.scatter(x=output2['victory'], y=output2['arena_rate'])
plt.scatter(x=output2['victory'], y=output2['attendance'])
# plt.plot(output['setu'], output['arena_rate'], marker='.')

# %%
import seaborn as sns
import japanize_matplotlib

fig, ax = plt.subplots(figsize=(16, 9))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlabel("勝数", fontsize=16) # x軸ラベル
plt.ylabel("収容率平均", fontsize=16) # y軸ラベル

# sns.scatterplot(x='victory', y='arena_rate', hue='home_team', data=output2, ax=ax)
grid = sns.scatterplot(x='victory', y='attendance', hue='home_team', data=output2, ax=ax)

# %%
# 外れ値(三遠)除外
# output2_drop = output2.drop(3, axis=0)
# 外れ値(三遠,新潟)除外
# output2_drop = output2.drop(3, axis=0).drop(13, axis=0)
# 三遠、東京
output2_drop = output2.drop(3, axis=0).drop(0, axis=0)
# output2_drop = output2
output2_drop

# statsmodelsを使った回帰分析
import statsmodels.api as sm
from sklearn import linear_model

victory = output2_drop[['victory']]
# arena_rate = output2_drop[['arena_rate']]
arena_rate = output2_drop[['attendance']]

model = linear_model.LinearRegression()
model.fit(victory.values, arena_rate.values)

sm_model = sm.OLS(arena_rate, sm.add_constant(victory))
result = sm_model.fit(disp=0)
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             attendance   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.249
# Method:                 Least Squares   F-statistic:                     5.965
# Date:                Tue, 30 Jun 2020   Prob (F-statistic):             0.0285
# Time:                        12:44:46   Log-Likelihood:                -128.14
# No. Observations:                  16   AIC:                             260.3
# Df Residuals:                      14   BIC:                             261.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1568.4375    735.983      2.131      0.051     -10.089    3146.964
# victory       84.3104     34.520      2.442      0.028      10.272     158.348
# ==============================================================================
# Omnibus:                        0.074   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.964   Jarque-Bera (JB):                0.120
# Skew:                           0.094   Prob(JB):                        0.942
# Kurtosis:                       2.619   Cond. No.                         80.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))

# %%
# 回帰直線
plt.rcParams["figure.figsize"] = [15,7] # 図の縦横のサイズ([横(inch),縦(inch)])
plt.rcParams["font.size"] = 15 # フォントサイズ デフォルト12
plt.title("scatter")
plt.xlabel("victory")
plt.ylabel("arena_rate")
plt.scatter(victory, arena_rate, s=20, alpha=0.5)
plt.plot(victory.values, model.predict(victory.values), color='black')

# %%
sanen_data = b1[(b1['home_team'] == '三遠') & (b1['home_away'] == 'home')]
# sanen_data = b1[(b1['home_team'] == '三遠')]
sanen = sanen_data.set_index('date')
sanen
# Out:
#        setu home_team home_victory  home_score away_team  away_score  \
# date
# 10.16     3        三遠         lose          71        横浜          80
# 10.19     4        三遠         lose          72      SR渋谷          87
# 10.20     4        三遠         lose          73      SR渋谷          85
# 11.02     7        三遠         lose          62        大阪          80
# 11.03     7        三遠         lose          70        大阪          87
# 12.11    11        三遠         lose          61        三河          66
# 12.15    12        三遠         lose          65        新潟          83
# 12.16    12        三遠          win          67        新潟          64
# 12.29    15        三遠         lose          61        京都          75
# 12.30    15        三遠         lose          71        京都          82
# 1.15     17        三遠         lose          73        川崎          83
# 1.25     19        三遠         lose          56        千葉          75
# 1.26     19        三遠         lose          65        千葉          91
# 2.01     21        三遠         lose          75       宇都宮          94
# 2.02     21        三遠         lose          50       宇都宮          87
# 2.15     23        三遠         lose          64      名古屋D          79
# 2.16     23        三遠          win          66      名古屋D          63
# 3.14     28        三遠         lose          73        富山          95
# 3.15     28        三遠          win          80        富山          79
#
#       home_away  attendance arena  arena_rate
# date
# 10.16      home        3399    豊橋         169
# 10.19      home        2783    浜松          35
# 10.20      home        2345    浜松          29
# 11.02      home        2504    豊橋         125
# 11.03      home        2798    豊橋         139
# 12.11      home        2204    豊橋         110
# 12.15      home        3013    豊橋         150
# 12.16      home        1916    豊橋          95
# 12.29      home        2424    豊橋         121
# 12.30      home        2810    豊橋         140
# 1.15       home        2056    豊橋         102
# 1.25       home        3036    豊橋         151
# 1.26       home        3846    豊橋         191
# 2.01       home        4649    浜松          58
# 2.02       home        4722    浜松          59
# 2.15       home        3458    豊橋         172
# 2.16       home        4408    豊橋         219
# 3.14       home           0    豊橋           0
# 3.15       home           0    豊橋           0

# %%
# 積み上げで表示
fig, ax = plt.subplots(figsize=(16, 9))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
sanen.attendance.plot(title='a', kind='bar', stacked=True, ax=ax)
