# %% [markdown]
# [B.LEAGUE（Bリーグ）公式サイト](https://www.bleague.jp/about/management/)

# %%
import pandas as pd

# B1
b1_data = pd.DataFrame({
            'チーム名': [
                '北海道', 
                '秋田', 
                '宇都宮', 
                '千葉', 
                'A東京', 
                'SR渋谷', 
                '川崎',
                '横浜', 
                '新潟', 
                '富山', 
                '三遠',
                '三河',
                '名古屋D',
                '滋賀',
                '京都',
                '大阪',
                '福岡',
                '琉球'
            ],
            '入場料収入': [
                226984,
                170164,
                433857,
                416258,
                250589,
                216555,
                208836,
                142465,
                198458,
                163866,
                139909,
                166581,
                126779,
                131398,
                97419,
                128796,
                100836,
                355863
            ],
            'スポンサー収入': [
                308104,
                296598,
                467110,
                776973,
                878325,
                446445,
                294569,
                455079,
                256180,
                218031,
                366379,
                982418,
                712358,
                268174,
                320924,
                650668,
                272633,
                467890
            ],
            '物販収入': [
                65078, 
                41070, 
                162332, 
                170614, 
                44454, 
                1676, 
                94221, 
                16256, 
                34876, 
                30383, 
                42105,
                65531, 
                11898, 
                12218, 
                19406, 
                40588, 
                16833, 
                128155
            ],
            'ユース・スクール関連収入': [
                47317, 
                24400, 
                101808, 
                48944,
                12478,
                7127,
                12300,
                135486,
                44534,
                18939,
                37406,
                11581,
                20854,
                34003,
                43710,
                100073,
                7552,
                8664
            ],
            '配分金': [
                54037,
                51500,
                66341,
                71880,
                51407,
                51578,
                30000,
                37012,
                42418,
                45040,
                35075,
                46906,
                34207,
                33491,
                30000,
                50598,
                30000,
                56176
            ],
            'その他': [
                88609,
                95484,
                139288,
                276994,
                140657,
                16588,
                25063,
                25364,
                43991,
                44863,
                81711,
                349472,
                27460,
                83208,
                25817,
                393242,
                29076,
                100313
            ],
            })
b1_data_index = b1_data.set_index('チーム名')

# データの正規化
b1_data_index_normalize = b1_data_index.div(b1_data_index.sum(1), axis=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# 積み上げで表示
fig, ax = plt.subplots(figsize=(16, 9))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
b1_data_index.plot(title='B1 営業収入', kind='bar', stacked=True, ax=ax).legend(bbox_to_anchor=(-0.1, 0.5), loc='upper right')
plt.text(-3, 1, '(単位:千円)')

# 割合で表示
fig, ax = plt.subplots(figsize=(16, 9))
b1_data_index_normalize.plot(title='B1 営業収入割合', kind='bar', stacked=True, ax=ax).legend(bbox_to_anchor=(-0.1, 0.5), loc='upper right')

# %%
import pandas as pd

# B2
b2_data = pd.DataFrame({
            'チーム名': [
                '青森',
                '仙台',
                '山形',
                '福島',
                '茨城',
                '群馬',
                '東京Z',
                '八王子',
                '金沢',
                '信州',
                'FE名古屋',
                '西宮',
                '奈良',
                '島根',
                '広島',
                '香川',
                '愛媛',
                '熊本',
            ],
            '入場料収入': [
                36541, 
                115048,
                31620,
                40262,
                81597,
                32777,
                43042,
                26685,
                17275,
                98547,
                40350,
                56251,
                65806,
                105990,
                126542,
                23032,
                69384,
                143981
            ],
            'スポンサー収入': [
                100223,
                192795,
                177860,
                118762,
                256259,
                95879,
                136741,
                179399,
                105641,
                161398,
                294960,
                169241,
                105918,
                234535,
                246446,
                94893,
                90753,
                201455
            ],
            '物販収入': [
                12603,
                34081,
                10104,
                11354,
                26213,
                6876,
                13006,
                6664,
                7096,
                25249,
                8364,
                5992,
                19494,
                14015,
                36379,
                2738,
                4023,
                30502
            ],
            'ユース・スクール関連収入': [
                9600,
                13604,
                24183,
                10005,
                11716,
                3906,
                2891,
                281,
                3600,
                0,
                22944,
                24602,
                39053,
                16988,
                17668,
                15040,
                9409,
                9710
            ],
            '配分金': [
                10800,
                21855,
                15200,
                12811,
                19808,
                17822,
                20999,
                10001,
                10284,
                19329,
                14565,
                25607,
                19264,
                20548,
                20159,
                10000,
                15107,
                26823
            ],
            'その他': [
                16230,
                47731,
                49273,
                23241,
                45924,
                11414,
                32788,
                7413,
                6788,
                24900,
                7668,
                28378,
                9805,
                64919,
                28182,
                41521,
                13163,
                33208
            ],
            })
b2_data_index = b2_data.set_index('チーム名')

# データの正規化
b2_data_index_normalize = b2_data_index.div(b2_data_index.sum(1), axis=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# 積み上げで表示
fig, ax = plt.subplots(figsize=(16, 9))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
b2_data_index.plot(title='B2 営業収入', kind='bar', stacked=True, ax=ax).legend(bbox_to_anchor=(-0.1, 0.5), loc='upper right')
plt.text(-3, 1, '(単位:千円)')

# 割合で表示
fig, ax = plt.subplots(figsize=(16, 9))
b2_data_index_normalize.plot(title='B2 営業収入割合', kind='bar', stacked=True, ax=ax).legend(bbox_to_anchor=(-0.1, 0.5), loc='upper right')

# %%
import pandas as pd

# B2
comparison = pd.DataFrame({
            'チーム名': ['B1平均', 'B2平均', 'ロボッツ'],
            '入場料収入': [204201, 64152, 81597],
            'スポンサー収入': [468825, 164620, 256259],
            '物販収入': [55427, 15264, 26213],
            'ユース・スクール関連収入': [39843, 13067, 11716],
            '配分金': [45426, 17277, 19808],
            'その他': [110400, 27364, 45924],
            })
comparison_index = comparison.set_index('チーム名')

# データの正規化
comparison_index_normalize = comparison_index.div(comparison_index.sum(1), axis=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# 積み上げで表示
fig, ax = plt.subplots(figsize=(16, 9))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
comparison_index.plot(title='営業収入比較', kind='bar', stacked=True, ax=ax).legend(bbox_to_anchor=(-0.1, 0.5), loc='upper right')
plt.text(-1, 1, '(単位:千円)')

# 割合で表示
fig, ax = plt.subplots(figsize=(16, 9))
comparison_index_normalize.plot(title='営業収入割合比較', kind='bar', stacked=True, ax=ax).legend(bbox_to_anchor=(-0.1, 0.5), loc='upper right')
